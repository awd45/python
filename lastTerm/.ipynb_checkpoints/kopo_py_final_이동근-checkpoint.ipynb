# %% [markdown]
# ### 1. [데이터 불러오기] MYSQL에서 KOPO_PRODUCT_VOLUME 테이블을 불러온 후 ORACLE 테이블에KOPO_PY_{이름}_FINAL1 테이블로 생성하세요

# %%
# PANDAS 패키지 불러오기
import pandas as pd 
import pymysql 
import psycopg2 as pg2
from sqlalchemy import create_engine 
 
# DB 커넥션 열기
#engine_oracle = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl')
engine_mysql = create_engine('mysql+pymysql://root:P@ssw0rd@192.168.110.112:3306/kopo')
#engine_postgre = create_engine('postgresql+psycopg2://kopo:kopo@192.168.110.111:5432/kopo')

# DB 테이블을 읽어 Data Frame 변수에 저장하기
myData = pd.read_sql_query('SELECT * FROM KOPO_PRODUCT_VOLUME ', engine_mysql) 
myData
# Out:
#     REGIONID PRODUCTGROUP YEARWEEK     VOLUME
# 0        A01       ST0002   201512   151750.0
# 1        A01       ST0001   201520   645626.0
# 2        A01       ST0002   201520   125863.0
# 3        A01       ST0001   201515   810144.0
# 4        A01       ST0002   201515   128999.0
# 5        A01       ST0001   201518   671464.0
# 6        A01       ST0002   201518   134467.0
# 7        A01       ST0001   201513   470040.0
# 8        A01       ST0002   201513   140297.0
# 9        A01       ST0001   201511   524787.0
# 10       A01       ST0002   201511   145509.0
# 11       A01       ST0001   201516   764927.0
# 12       A01       ST0002   201516   140313.0
# 13       A01       ST0001   201519   682757.0
# 14       A01       ST0002   201519   128668.0
# 15       A01       ST0001   201514   428195.0
# 16       A01       ST0002   201514   137488.0
# 17       A01       ST0001   201512   486509.0
# 18       A01       ST0001   201517   697502.0
# ...

# %%
# 데이터 저장
resultname='KOPO_PY_LDG_FINAL1'
myData.to_sql(resultname, engine_mysql, if_exists='replace', index=False)

# %% [markdown]
# ### 2. [데이터 조작하기] ORACLE에서 KOPO_PRODUCT_VOLUME 테이블을 불러온 후 2016년도 자료만 남기고 ORACLE 테이블에 KOPO_PY_{이름}_FINAL2 테이블로 생성하세요

# %%
import pandas as pd
from sqlalchemy import create_engine 
 
# DB 커넥션 열기
engine = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl') 

# DB 테이블을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_sql_query('select * from KOPO_PRODUCT_VOLUME where substr(to_char(yearweek),1,4) = 2016', engine)

# 컬럼해더 재정의
customerData.columns = ['regionid','productgroup','yearweek','volume']

customerData = pd.DataFrame(customerData)
customerData

customerData
# Out:
#    regionid productgroup yearweek     volume
# 0       A01       ST0001   201605   661049.0
# 1       A01       ST0002   201605   231214.0
# 2       A01       ST0001   201603   531372.0
# 3       A01       ST0002   201603   152763.0
# 4       A01       ST0001   201601   651243.0
# 5       A01       ST0002   201601   162801.0
# 6       A01       ST0001   201608   671116.0
# 7       A01       ST0002   201608   130000.0
# 8       A01       ST0001   201606   881536.0
# 9       A01       ST0002   201606   172230.0
# 10      A01       ST0001   201604   585025.0
# 11      A01       ST0002   201604   197057.0
# 12      A01       ST0001   201602   573198.0
# 13      A01       ST0002   201602   137186.0
# 14      A01       ST0001   201607   790430.0
# 15      A01       ST0002   201607   161324.0
# 16      A01       ST0001   201623   768124.0
# 17      A01       ST0002   201623   161983.0
# 18      A01       ST0001   201621   721991.0
# 19      A01       ST0002   201621   205984.0
# ...

# %%
# 데이터 저장
resultname1='KOPO_PY_LDG_FINAL2'
customerData.to_sql(resultname1, engine, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-6-795f54072d2f> in <module>()
#       1 # 데이터 저장
#       2 resultname1='KOPO_PY_LDG_FINAL5'
# ----> 3 customerData.to_sql(resultname1, engine, if_exists='replace', index=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, flavor, schema, if_exists, index, index_label, chunksize, dtype)
#    1532         sql.to_sql(self, name, con, flavor=flavor, schema=schema,
#    1533                    if_exists=if_exists, index=index, index_label=index_label,
# -> 1534                    chunksize=chunksize, dtype=dtype)
#    1535
#    1536     def to_pickle(self, path, compression='infer',
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, flavor, schema, if_exists, index, index_label, chunksize, dtype)
# ...

# %%
customerData.dtypes
# Out:
# regionid         object
# productgroup     object
# yearweek         object
# volume          float64
# dtype: object

# %%
a = "abcd"

# %%
a[3]=="d"
# Out:
# True

# %% [markdown]
# ### 3. [스크래핑] https://www.timeanddate.com/holidays/south-korea/ 사이트에서 화면에 보이는 테이블의 holiday정보를 스크래핑 하여 아래 이미지와 동일한 컬럼의 정보를 추출한 후 KOPO_PY_{이름}_FINAL3 테이블로 생성하세요 [심심하면 Date도 같이..저장하세요]

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('https://www.timeanddate.com/holidays/south-korea/')
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, 'html.parser')

# html 부분구조 가져오기
find_tag = bs.find("div")
print(find_tag)
# Out:
# <div class="wrapper"><div class="banner" id="header"><div class="fixed">
# <div id="logo"><a href="/" rel="home"><img alt="timeanddate.com" src="//c.tadst.com/gfx/n/tad-logo-com3.png" title="Home page timeanddate.com"/></a></div>
# </div></div>
# <div id="ad-wrap"><div class="fixed" id="ad-wrap2"><div id="ad7"><div id="div-gpt-com-728x90" style="width:728px;height:90px;"><script type="text/javascript">
# googletag.cmd.push(function(){googletag.display('div-gpt-com-728x90'); });
# </script>
# ...

# %%
# html 태그 속성으로 찾기
find_attr = bs.find("table",{"class":"zebra fw tb-cl tb-hover"})
print(find_attr)
# Out:
# <table class="zebra fw tb-cl tb-hover"><thead><tr class="head"><th rowspan="2">Date</th><th class="sep" rowspan="2">Weekday</th><th class="sep" rowspan="2">Holiday Name</th><th class="sep" rowspan="2">Holiday Type</th></tr><tr class="head"></tr></thead><tbody><tr class="c0" id="tr0"><th class="nw">Jan 1</th><td class="nw">Monday</td><td><a href="/holidays/southkorea/new-year-day">New Year's Day</a></td><td>National holiday</td></tr><tr class="c1" id="tr1"><th class="nw">Feb 9</th><td class="nw">Friday</td><td><a href="/holidays/southkorea/winter-olympics-2018">2018 Winter Olympics start</a></td><td>Observance</td></tr><tr class="c0" id="tr2"><th class="nw">Feb 14</th><td class="nw">Wednesday</td><td><a href="/holidays/southkorea/valentines-day">Valentine's Day</a></td><td>Observance</td></tr><tr class="c1" id="tr3"><th class="nw">Feb 15</th><td class="nw">Thursday</td><td><a href="/holidays/southkorea/seollal-holiday-1">Seollal Holiday</a></td><td>National holiday</td></tr><tr class=
# ...

# %%
find_part = find_attr.findAll("th")
print(find_part)
# Out:
# [<th rowspan="2">Date</th>, <th class="sep" rowspan="2">Weekday</th>, <th class="sep" rowspan="2">Holiday Name</th>, <th class="sep" rowspan="2">Holiday Type</th>, <th class="nw">Jan 1</th>, <th class="nw">Feb 9</th>, <th class="nw">Feb 14</th>, <th class="nw">Feb 15</th>, <th class="nw">Feb 16</th>, <th class="nw">Feb 17</th>, <th class="nw">Feb 25</th>, <th class="nw">Mar 1</th>, <th class="nw">Mar 9</th>, <th class="nw">Mar 18</th>, <th class="nw">Mar 20</th>, <th class="nw">Apr 5</th>, <th class="nw">May 1</th>, <th class="nw">May 5</th>, <th class="nw">May 7</th>, <th class="nw">May 8</th>, <th class="nw">May 15</th>, <th class="nw">May 22</th>, <th class="nw">Jun 6</th>, <th class="nw">Jun 13</th>, <th class="nw">Jun 21</th>, <th class="nw">Jul 17</th>, <th class="nw">Aug 15</th>, <th class="nw">Sep 23</th>, <th class="nw">Sep 23</th>, <th class="nw">Sep 24</th>, <th class="nw">Sep 25</th>, <th class="nw">Sep 26</th>, <th class="nw">Oct 1</th>, <th class="nw">Oct 3</th>, <th cl
# ...

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('https://www.timeanddate.com/holidays/south-korea/')
resp.encoding='utf-8'
html = resp.text
bs = bs4.BeautifulSoup(html, 'html.parser')

# html 부분구조 가져오기
columns=bs.select('table > thead > tr > th')
columns
type(columns)

columnlist=[]
for column in columns:
    columnlist.append(column.text)
df=pd.DataFrame(columns=columnlist)

df
# Out:
# Empty DataFrame
# Columns: [Date, Weekday, Holiday Name, Holiday Type]
# Index: []

# %%
contents=bs.select('table  > tbody > tr')
dfcontent=[]
alldfcontents=[]
contents
# Out:
# [<tr class="c0" id="tr0"><th class="nw">Jan 1</th><td class="nw">Monday</td><td><a href="/holidays/southkorea/new-year-day">New Year's Day</a></td><td>National holiday</td></tr>,
#  <tr class="c1" id="tr1"><th class="nw">Feb 9</th><td class="nw">Friday</td><td><a href="/holidays/southkorea/winter-olympics-2018">2018 Winter Olympics start</a></td><td>Observance</td></tr>,
#  <tr class="c0" id="tr2"><th class="nw">Feb 14</th><td class="nw">Wednesday</td><td><a href="/holidays/southkorea/valentines-day">Valentine's Day</a></td><td>Observance</td></tr>,
#  <tr class="c1" id="tr3"><th class="nw">Feb 15</th><td class="nw">Thursday</td><td><a href="/holidays/southkorea/seollal-holiday-1">Seollal Holiday</a></td><td>National holiday</td></tr>,
#  <tr class="c0" id="tr4"><th class="nw">Feb 16</th><td class="nw">Friday</td><td><a href="/holidays/southkorea/seollal-holiday-2">Seollal</a></td><td>National holiday</td></tr>,
# ...

# %%
tds =contents[0].findAll("td")
    for td in tds:
        emptyList.appnd(td.text)
# Out:
#   File "<ipython-input-51-f53f8be896d0>", line 2
#     for td in tds:
#     ^
# IndentationError: unexpected indent

# %%
tds=contents[0].select("td")
tds
# Out:
# [<td class="nw">Monday</td>,
#  <td><a href="/holidays/southkorea/new-year-day">New Year's Day</a></td>,
#  <td>National holiday</td>]

# %%
for content in contents:
    tds=content.findAll("td")
    dfcontent.append(td.text)
dfcontent
# Out:
# ['Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
#  'Observance',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-58-548abb413ef8> in <module>()
#       7     alldfcontents.append(dfcontent)
#       8     dfcontent=[]
# ----> 9 df=pd.DataFrame(columns=columnlist, data=alldfcontents)
#      10 df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     367                     if is_named_tuple(data[0]) and columns is None:
#     368                         columns = data[0]._fields
# --> 369                     arrays, columns = _to_arrays(data, columns, dtype=dtype)
#     370                     columns = _ensure_index(columns)
#     371
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _to_arrays(data, columns, coerce_float, dtype)
#    6282     if isinstance(data[0], (list, tuple)):
# ...
