# %%
# PANDAS 패키지 불러오기
import pandas as pd
 
# CSV 파일을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_csv("C:/Users/SMART-01/python_ldg/dataset/CUSTOMERDATA.csv")

# 컬럼해더 재정의
customerData.columns = ['CUSTID','AVGPRICE','EMI','DEVICECOUNT','PRODUCTAGE','CUSTTYPE']

## 데이터프레임 생성
customerData = pd.DataFrame(customerData)
customerData
# Out:
#      CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0    A13566  4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1    A14219  3642.441950    2          4.0    2.682023      Sleeping-dog
# 2    A15312  3653.884565    2          5.0    3.208202      Sleeping-dog
# 3    A16605  3713.211107    2          6.6    0.900000        Early-bird
# 4    B10634  3391.074215    2          4.2    2.453656      Sleeping-dog
# 5    B16849  3755.263391    2          4.7    2.786665      Sleeping-dog
# 6    B18816  3213.911446    2          6.4    0.900000        Early-bird
# 7    C10639  3516.500000    2          5.2    2.564830  Big-Screen-lover
# 8    C12717  3732.900000    2          5.7    2.069995  Big-Screen-lover
# 9    C15050  4020.173425    2          4.9    3.013440      Sleeping-dog
# 10   C18306  4005.005142    2          4.7    3.113618      Sleeping-dog
# 11   C18622  3246.000000    1          5.0    1.891624  Big-Screen-lover
# ...

# %%
## 조건 설정
answer1 = customerData[ (customerData.EMI==3) & (customerData.DEVICECOUNT>5) ]
answer1
# Out:
#      CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0    A13566  4273.900000    3          6.4    1.679181  Big-Screen-lover
# 27   F17131  3179.708359    3          6.5    1.100000        Early-bird
# 33   G16437  3787.328898    3          6.7    1.000000        Early-bird
# 36   G18402  3402.199381    3          6.5    1.000000        Early-bird
# 40   H16326  3988.935304    3          6.5    0.900000        Early-bird
# 45   I12899  3018.895637    3          6.4    0.900000        Early-bird
# 51   J10809  3676.135627    3          6.5    0.800000        Early-bird
# 52   J15083  2811.265932    3          6.0    0.900000        Early-bird
# 53   J16445  3041.848186    3          6.4    0.800000        Early-bird
# 60   L13892  3263.515145    3          6.7    1.100000        Early-bird
# 67   N13273  3839.694732    3          6.9    1.100000        Early-bird
# 95   R16364  3592.353540    3          6.2    0.900000        Early-bird
# ...

# %%
## 조건 설정
answer2 = customerData.query('EMI == 3 & DEVICECOUNT > 5')
answer2
# Out:
#      CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0    A13566  4273.900000    3          6.4    1.679181  Big-Screen-lover
# 27   F17131  3179.708359    3          6.5    1.100000        Early-bird
# 33   G16437  3787.328898    3          6.7    1.000000        Early-bird
# 36   G18402  3402.199381    3          6.5    1.000000        Early-bird
# 40   H16326  3988.935304    3          6.5    0.900000        Early-bird
# 45   I12899  3018.895637    3          6.4    0.900000        Early-bird
# 51   J10809  3676.135627    3          6.5    0.800000        Early-bird
# 52   J15083  2811.265932    3          6.0    0.900000        Early-bird
# 53   J16445  3041.848186    3          6.4    0.800000        Early-bird
# 60   L13892  3263.515145    3          6.7    1.100000        Early-bird
# 67   N13273  3839.694732    3          6.9    1.100000        Early-bird
# 95   R16364  3592.353540    3          6.2    0.900000        Early-bird
# ...

# %% [markdown]
# ### kopo_customerdata 테이블에서
# ### gender == male 이면서 email > 0 인
# ### 데이터를 추출하세요!

# %%
import pandas as pd
from sqlalchemy import create_engine 
# DB 커넥션 열기
engine = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl') 

# DB 테이블을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_sql_query('SELECT * FROM kopo_customerdata', engine) 
customerData
# Out:
#        customercode statename  st  gender  dob  gender1  email  fest_cnt  \
# 0           1503989    State2   2    Male    0        1      1         0
# 1           1190338    State2   2    Male    0        1      0         1
# 2           1424715    State2   2  Female    0        2      0         0
# 3           2483305    State2   2    Male    0        1      0         1
# 4           1178802    State2   2    Male    0        1      0         1
# 5            859044    State2   2    Male    0        1      0         0
# 6            734198    State2   2  Female    0        2      0         0
# 7           1443485    State2   2  Female    0        2      0         0
# 8           2340520    State2   2    Male    0        1      0         1
# 9            697949    State2   2    Male    0        1      0         1
# 10           385031    State2   2    Male    0        1      0         1
# 11          1944258    State2   2  Female    0        2      0         0
# ...

# %%
## 조건 설정
answer1 = customerData[ (customerData.gender=='Male') & (customerData.email> 0) ]
answer1
# Out:
#        customercode statename  st gender  dob  gender1  email  fest_cnt  \
# 0           1503989    State2   2   Male    0        1      1         0
# 16          1154228    State2   2   Male    0        1      1         0
# 81           393246    State2   2   Male    0        1      1         1
# 206         2532568    State2   2   Male    1        1      1         0
# 216          487928    State2   2   Male    0        1      1         0
# 226         2452240    State2   2   Male    1        1      1         1
# 299         1295854    State2   2   Male    1        1      1         2
# 308          554757    State2   2   Male    0        1      1         0
# 330          761018    State2   2   Male    1        1      1         0
# 367         2191152    State2   2   Male    0        1      1         1
# 375          867914    State2   2   Male    0        1      1         0
# 415         1804886    State2   2   Male    0        1      1         1
# ...

# %%
## 조건 설정
answer2 = customerData.query('gender == "Male" & email > 0')
answer2
# Out:
#        customercode statename  st gender  dob  gender1  email  fest_cnt  \
# 0           1503989    State2   2   Male    0        1      1         0
# 16          1154228    State2   2   Male    0        1      1         0
# 81           393246    State2   2   Male    0        1      1         1
# 206         2532568    State2   2   Male    1        1      1         0
# 216          487928    State2   2   Male    0        1      1         0
# 226         2452240    State2   2   Male    1        1      1         1
# 299         1295854    State2   2   Male    1        1      1         2
# 308          554757    State2   2   Male    0        1      1         0
# 330          761018    State2   2   Male    1        1      1         0
# 367         2191152    State2   2   Male    0        1      1         1
# 375          867914    State2   2   Male    0        1      1         0
# 415         1804886    State2   2   Male    0        1      1         1
# ...

# %% [markdown]
# ### 원하는 컬럼 조회하기

# %%
# PANDAS 패키지 불러오기
import pandas as pd
 
# CSV 파일을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_csv("C:/Users/SMART-01/python_ldg/dataset/CUSTOMERDATA.csv")

# 컬럼해더 재정의
customerData.columns = ['CUSTID','AVGPRICE','EMI','DEVICECOUNT','PRODUCTAGE','CUSTTYPE']

## 데이터프레임 생성
customerData = pd.DataFrame(customerData)

# 데이터프레임 리스트 활용하기
customerDataC = customerData[['CUSTID','EMI']]
customerDataC
# Out:
#      CUSTID  EMI
# 0    A13566    3
# 1    A14219    2
# 2    A15312    2
# 3    A16605    2
# 4    B10634    2
# 5    B16849    2
# 6    B18816    2
# 7    C10639    2
# 8    C12717    2
# 9    C15050    2
# 10   C18306    2
# 11   C18622    1
# 12   C19178    2
# 13   D11795    2
# 14   D13030    2
# 15   D15289    2
# 16   D17241    2
# 17   D17880    2
# 18   E10778    2
# 19   E11917    2
# 20   E16075    2
# 21   E16221    2
# 22   E18145    2
# 23   E19404    2
# 24   F10222    2
# 25   F12979    2
# 26   F14866    2
# 27   F17131    3
# 28   F18646    2
# 29   F19938    2
# ..      ...  ...
# 120  U16894    2
# 121  U17547    2
# 122  U17748    2
# 123  V10654    2
# 124  V16516    2
# 125  V16704    2
# 126  V18566    3
# 127  V19072    2
# 128  W10832    2
# 129  W13032    2
# 130  W13404    3
# 131  W13995    2
# 132  W16193    2
# 133  W18228    2
# 134  X10158    2
# 135  X13390    3
# 136  X14259    2
# 137  X19598    2
# 138  X19768    2
# 139  Y10906    2
# ...

# %%
# filter 함수 활용하기
customerDataC = customerData.filter(items=['CUSTID','EMI'])
customerDataC.head()
# Out:
#    CUSTID  EMI
# 0  A13566    3
# 1  A14219    2
# 2  A15312    2
# 3  A16605    2
# 4  B10634    2

# %% [markdown]
# ### kopo_customerdata 테이블에서
# ### customercode, statename, gender, total_amount 컬럼만
# ### 추출하세요

# %%
import pandas as pd
from sqlalchemy import create_engine 
# DB 커넥션 열기
engine = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl') 

# DB 테이블을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_sql_query('SELECT * FROM kopo_customerdata', engine) 

# 데이터프레임 리스트 활용하기
customerDataC = customerData[['customercode','statename','gender','total_amount']]
customerDataC
# Out:
#        customercode statename  gender  total_amount
# 0           1503989    State2    Male         30300
# 1           1190338    State2    Male         46500
# 2           1424715    State2  Female         22700
# 3           2483305    State2    Male         31400
# 4           1178802    State2    Male         44900
# 5            859044    State2    Male         38300
# 6            734198    State2  Female         19900
# 7           1443485    State2  Female         14800
# 8           2340520    State2    Male         24400
# 9            697949    State2    Male         30400
# 10           385031    State2    Male         30300
# 11          1944258    State2  Female         34300
# 12          2029521    State2  Female         14900
# 13          1429192    State2    Male         16300
# 14           892851    State2    Male         25000
# 15          1554976    State2    Male         27500
# 16          1154228    State2    Male         18200
# ...

# %% [markdown]
# ###  인덱스를 활용하여 조회하기 행과 열을 이용하자

# %%
import pandas as pd
from sqlalchemy import create_engine 
# DB 커넥션 열기
engine = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl') 

# DB 테이블을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_sql_query('SELECT * FROM kopo_customerdata', engine) 

# 데이터프레임 리스트 활용하기
customerDataC = customerData[['customercode','statename','gender','total_amount']]
customerDataC
# Out:
#        customercode statename  gender  total_amount
# 0           1503989    State2    Male         30300
# 1           1190338    State2    Male         46500
# 2           1424715    State2  Female         22700
# 3           2483305    State2    Male         31400
# 4           1178802    State2    Male         44900
# 5            859044    State2    Male         38300
# 6            734198    State2  Female         19900
# 7           1443485    State2  Female         14800
# 8           2340520    State2    Male         24400
# 9            697949    State2    Male         30400
# 10           385031    State2    Male         30300
# 11          1944258    State2  Female         34300
# 12          2029521    State2  Female         14900
# 13          1429192    State2    Male         16300
# 14           892851    State2    Male         25000
# 15          1554976    State2    Male         27500
# 16          1154228    State2    Male         18200
# ...

# %%
# 인덱스로 조회하기
dfc1 = customerData.iloc[0:1,:]
dfc1
# Out:
#   customercode statename  st gender  dob  gender1  email  fest_cnt  \
# 0      1503989    State2   2   Male    0        1      1         0
#
#    total_amount  ac_amount  av_amount  ha_amount  emi_ce_amount  is_highend  \
# 0         30300          0      30300          0              0           0
#
#    cnt_vist  gap_visit
# 0         1          0

# %%
dfc2 = customerData.iloc[0:6,[1,3]]
dfc2
# Out:
#   statename  gender
# 0    State2    Male
# 1    State2    Male
# 2    State2  Female
# 3    State2    Male
# 4    State2    Male
# 5    State2    Male

# %%
dfc3 = customerData.loc[0:2,["statename","gender"]]
dfc3
# Out:
#   statename  gender
# 0    State2    Male
# 1    State2    Male
# 2    State2  Female
