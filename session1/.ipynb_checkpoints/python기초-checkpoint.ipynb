# %% [markdown]
# ### 주요단축키, 자료형

# %%
a=3
b=5

# %%
a.conjugate
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-621b182b3e00> in <module>()
# ----> 1 a.conjugateType
#
# AttributeError: 'int' object has no attribute 'conjugateType'

# %%
a=3
A=5

print(a)
print(A)
# Out:
# 3
# 5

# %%
3A = 2
# Out:
#   File "<ipython-input-6-5623cf5289d8>", line 1
#     3A = 2
#      ^
# SyntaxError: invalid syntax

# %%
if = 3
# Out:
#   File "<ipython-input-7-d7549b45180c>", line 1
#     if = 3
#        ^
# SyntaxError: invalid syntax

# %%
# 파이썬 사칙연산
integer_value = 123
float_value = 12.456

# %%
type(integer_value)
# Out:
# int

# %%
# 1. 더하기 연산
sum = integer_value+float_value
print(sum)
# Out:
# 135.456

# %%
# 2. 곱하기연산
multiple = integer_value*float_value
print(multiple)
# Out:
# 1532.088

# %%
# 3. 나누기 연산
division = integer_value/float_value
print(division)
# Out:
# 9.8747591522158

# %%
# 4. 제곱연산
integer_value2 = int(float_value)
exponential = integer_value2**2
print(exponential)
# Out:
# 144

# %%
# 5. 나머지 연산
mod = integer_value%int(float_value)
print(mod)
# Out:
# 3

# %%
aType = "This is'String' value"
print(aType)
# Out:
# This is'String' value

# %%
bType = 'This is "String" value'
print(bType)
# Out:
# This is "String" value

# %%
cType = """This is 'String' value"""
print(cType)
# Out:
# This is 'String' value

# %%
a = "abc""def"
print(a)
# Out:
# abcdef

# %%
print("*"*20+" 문자열 연산 프로그램"+"*"*20)
# Out:
# ******************** 문자열 연산 프로그램********************

# %%
yearweek = "201801"
print(yearweek[0])
print(yearweek[0:4])
print(yearweek[4:])
# Out:
# 2
# 2018
# 01

# %%
yearweek = "2017W28"
print(yearweek.count('W'))
# Out:
# 1

# %%
print(yearweek.index('W'))
# Out:
# 4

# %%
delimeter = yearweek.index('W')
yearweek_new = yearweek[:delimeter]+yearweek[delimeter+1:]
print([yearweek_new])
# Out:
# ['201728']

# %%
yearweek_list = yearweek.split("W")
print(yearweek_list)
# Out:
# ['2017', '28']

# %%
head = "polytech"
tail = "student"
fullString = head+" "+tail
print(fullString)
# Out:
# polytech student

# %%
# 실습
testData2 = "Sec 2017W28 250"
testDataSplit2 = testData2.upper().split(" ")
testDataSplit2

print(testDataSplit2[0])
print(testDataSplit2[1].replace('W',''))
print(testDataSplit2[2])
# Out:
# SEC
# 201728
# 250

# %%
#리스트 연산
stockName = ["SEC"]
priceList = [120,130]
dateList = [201712,201713]

secinfo = stockName+priceList+[dateList]
print(secinfo)

#리스트 인덱싱
#secinfo=["SEC",120,130,[201712,201713]]
print(secinfo[1])
print(secinfo[3])
print(secinfo[3][0])
print(secinfo[0:3])
# Out:
# ['SEC', 120, 130, [201712, 201713]]
# 120
# [201712, 201713]
# 201712
# ['SEC', 120, 130]

# %%
#리스트 값 업데이트 하기
updateList = [120,130,140,150]
print(updateList)
updateList[2] = 180
print(updateList)

#리스트 값 삭제하기 구간 1<=인덱스<3
updateList[1:3] = []

print(updateList)
# Out:
# [120, 130, 140, 150]
# [120, 130, 180, 150]
# [120, 150]

# %%
functionList = [120,130,140,150]
#리스트에 요소 추가하기
functionList.append(100)  ## functionList.insert(3,100) 3번째 인덱스에 추가
functionList.extend([11,12])
print(functionList)
#리스트 정렬하기
functionList.sort(reverse = False)
print(functionList)
#값으로 인덱스 가져오기
print(functionList.index(150))
#리스트 자주사용하는 함수
print(len(functionList))
print(min(functionList))
print(max(functionList))
print(sum(functionList))
# Out:
# [120, 130, 140, 150, 100, 11, 12]
# [11, 12, 100, 120, 130, 140, 150]
# 6
# 7
# 11
# 150
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-fd23270de182> in <module>()
#      13 print(min(functionList))
#      14 print(max(functionList))
# ---> 15 print(sum(functionList))
#
# TypeError: 'float' object is not callable

# %%
#실습
testDataList = [120,150,300,500,1000,100,2000]
maxValue = max(testDataList)
print(maxValue)
minValue = min(testDataList)
print(minValue)

testDataList.pop(testDataList.index(maxValue))
testDataList.pop(testDataList.index(minValue))

print(testDataList)
# Out:
# 2000
# 100
# [120, 150, 300, 500, 1000]

# %%
averageSum = sum(testDataList)
averageCount = len(testDataList)

average = averageSum/averageCount
print(average)


# if averageCount!=0:
#         average = averageSum/averageCount
# elif
# else:
#             average = 1
# average
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-d782fea7627a> in <module>()
# ----> 1 averageSum = sum(testDataList)
#       2 averageCount = len(testDataList)
#       3
#       4 average = averageSum/averageCount
#       5 print(average)
#
# TypeError: 'float' object is not callable
