# %% [markdown]
# ### productage가 1보다작으면 1 2보다작으면2 3보다작으면3 이외는 5라고 새로운 컬럼 product_age_new를 생성하세요

# %%
# PANDAS 패키지 불러오기
import pandas as pd
 
# CSV 파일을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_csv("C:/Users/SMART-01/python_ldg/dataset/CUSTOMERDATA.csv")

# 컬럼해더 재정의
customerData.columns = ['CUSTID','AVGPRICE','EMI','DEVICECOUNT','PRODUCTAGE','CUSTTYPE']

## 데이터프레임 생성
customerData = pd.DataFrame(customerData)
customerData
# Out:
#      CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0    A13566  4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1    A14219  3642.441950    2          4.0    2.682023      Sleeping-dog
# 2    A15312  3653.884565    2          5.0    3.208202      Sleeping-dog
# 3    A16605  3713.211107    2          6.6    0.900000        Early-bird
# 4    B10634  3391.074215    2          4.2    2.453656      Sleeping-dog
# 5    B16849  3755.263391    2          4.7    2.786665      Sleeping-dog
# 6    B18816  3213.911446    2          6.4    0.900000        Early-bird
# 7    C10639  3516.500000    2          5.2    2.564830  Big-Screen-lover
# 8    C12717  3732.900000    2          5.7    2.069995  Big-Screen-lover
# 9    C15050  4020.173425    2          4.9    3.013440      Sleeping-dog
# 10   C18306  4005.005142    2          4.7    3.113618      Sleeping-dog
# 11   C18622  3246.000000    1          5.0    1.891624  Big-Screen-lover
# ...

# %%
# numpy 라이브러리 
import numpy as np

#컬럼 추가 생성 및 조건에 따른 컬럼명 변경
customerData["PRODUCTAGE_NEW"] = np.\
where(customerData["PRODUCTAGE"] < 1, 1, customerData["PRODUCTAGE"])
customerData.head()
# Out:
#    CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0  A13566  4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219  3642.441950    2          4.0    2.682023      Sleeping-dog
# 2  A15312  3653.884565    2          5.0    3.208202      Sleeping-dog
# 3  A16605  3713.211107    2          6.6    0.900000        Early-bird
# 4  B10634  3391.074215    2          4.2    2.453656      Sleeping-dog
#
#    PRODUCTAGE_NEW
# 0        1.679181
# 1        2.682023
# 2        3.208202
# 3        1.000000
# 4        2.453656

# %%
# 1,2,3
# step = [1,2,3]
step = list(range(1,4))
maxValue = 5
customerData["PRODUCTAGE_NEW"] = np.where(customerData["PRODUCTAGE"] < step[0], step[0], \
                                          np.where(customerData["PRODUCTAGE"] < step[1], step[1], \
                                          np.where(customerData["PRODUCTAGE"] < step[2], step[2], \
                                          maxValue)))
                                                   
customerData.head()
# Out:
#    CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0  A13566  4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219  3642.441950    2          4.0    2.682023      Sleeping-dog
# 2  A15312  3653.884565    2          5.0    3.208202      Sleeping-dog
# 3  A16605  3713.211107    2          6.6    0.900000        Early-bird
# 4  B10634  3391.074215    2          4.2    2.453656      Sleeping-dog
#
#    PRODUCTAGE_NEW
# 0               2
# 1               3
# 2               5
# 3               1
# 4               3

# %%
#컬럼 추가 생성 및 조건에 따른 컬럼명 변경
def refining(df):
    if df['PRODUCTAGE'] < 1:
        return 1
    elif df['PRODUCTAGE'] < 2:
        return 2
    elif df['PRODUCTAGE'] < 3:
        return 3
    else:
        return 5

customerData["productage_new2"] =customerData.apply(refining, axis=1)
customerData.head()
# Out:
#    CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0  A13566  4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219  3642.441950    2          4.0    2.682023      Sleeping-dog
# 2  A15312  3653.884565    2          5.0    3.208202      Sleeping-dog
# 3  A16605  3713.211107    2          6.6    0.900000        Early-bird
# 4  B10634  3391.074215    2          4.2    2.453656      Sleeping-dog
#
#    PRODUCTAGE_NEW  productage_new2
# 0               2                2
# 1               3                3
# 2               5                5
# 3               1                1
# 4               3                3

# %%
# 데이터 정렬하기
customerData.sort_values(["CUSTID","AVGPRICE"], ascending=[True,False])
customerData.tail(5)
# Out:
#      CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 145  Z13253  3678.800000    2          5.9    2.463670  Big-Screen-lover
# 146  Z13534  3662.437527    3          6.6    0.900000        Early-bird
# 147  Z16428  3516.500000    2          5.8    2.371301  Big-Screen-lover
# 148  Z16735  3300.100000    2          5.6    1.704942  Big-Screen-lover
# 149  Z19835  3326.526183    2          6.7    1.200000        Early-bird
#
#      PRODUCTAGE_NEW  productage_new2
# 145               3                3
# 146               1                1
# 147               3                3
# 148               2                2
# 149               2                2

# %%
# 평균 구하기
meanValue = customerData.\
groupby(['CUSTTYPE','EMI'], as_index=True).\
mean()

# %%
meanValue
# Out:
#                          AVGPRICE  DEVICECOUNT  PRODUCTAGE  PRODUCTAGE_NEW  \
# CUSTTYPE         EMI
# Big-Screen-lover 1    3246.000000     5.000000    1.891624        2.000000
#                  2    3535.317391     5.508696    2.223247        2.804348
#                  3    4111.600000     6.400000    1.838520        2.333333
# Early-bird       1    2390.083736     6.300000    1.000000        2.000000
#                  2    3232.445885     6.460606    0.936364        1.242424
#                  3    3455.966035     6.475000    0.962500        1.437500
# Sleeping-dog     1    3185.918464     3.833333    2.357587        2.777778
#                  2    3504.298670     4.353659    2.724274        3.463415
#
#                       productage_new2
# CUSTTYPE         EMI
# Big-Screen-lover 1           2.000000
#                  2           2.804348
#                  3           2.333333
# Early-bird       1           2.000000
#                  2           1.242424
# ...

# %%
# 평균 구하기
meanValue = customerData.\
groupby(['EMI'], as_index=True).\
mean()
meanValue
# Out:
#         AVGPRICE  DEVICECOUNT  PRODUCTAGE  PRODUCTAGE_NEW  productage_new2
# EMI
# 1    3119.031810     4.163636    2.191810        2.636364         2.636364
# 2    3441.429664     5.375833    2.040539        2.600000         2.600000
# 3    3559.487188     6.463158    1.100819        1.578947         1.578947

# %%
# 평균 구하기
maxValue = customerData.\
groupby(['EMI'], as_index=True).\
max()

# %%
maxValue
# Out:
#      CUSTID     AVGPRICE  DEVICECOUNT  PRODUCTAGE      CUSTTYPE  \
# EMI
# 1    Y12458  3419.462596          6.3    2.994395  Sleeping-dog
# 2    Z19835  4166.533130          6.9    3.483573  Sleeping-dog
# 3    Z13534  4296.873743          6.9    2.055707    Early-bird
#
#      PRODUCTAGE_NEW  productage_new2
# EMI
# 1                 3                3
# 2                 5                5
# 3                 3                3

# %%
customerData["TEST"] = customerData["PRODUCTAGE"].rolling(window = 5, center = False).mean()
customerData.head(10)
# Out:
#    CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0  A13566  4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219  3642.441950    2          4.0    2.682023      Sleeping-dog
# 2  A15312  3653.884565    2          5.0    3.208202      Sleeping-dog
# 3  A16605  3713.211107    2          6.6    0.900000        Early-bird
# 4  B10634  3391.074215    2          4.2    2.453656      Sleeping-dog
# 5  B16849  3755.263391    2          4.7    2.786665      Sleeping-dog
# 6  B18816  3213.911446    2          6.4    0.900000        Early-bird
# 7  C10639  3516.500000    2          5.2    2.564830  Big-Screen-lover
# 8  C12717  3732.900000    2          5.7    2.069995  Big-Screen-lover
# 9  C15050  4020.173425    2          4.9    3.013440      Sleeping-dog
#
#        TEST
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4  2.184612
# 5  2.406109
# 6  2.049705
# 7  1.921030
# 8  2.155029
# 9  2.266986

# %%
customerData["PRODUCTAGE"][1]
# Out:
# 2.68202302093618

# %%
order = 5

# %%
suborder = 4

# %%
import math
suborder = math.floor(5/2)

# %%
list = []
for i in range(0,suborder):
    list.append(customerData["PRODUCTAGE"][0:i+suborder].mean())
list
# Out:
# [2.180601934487935, 2.5231351467625562]
