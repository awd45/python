# %%
# PANDAS 패키지 불러오기
import pandas as pd
 
# CSV 파일을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_csv("C:/Users/SMART-01/python_ldg/dataset/CUSTOMERDATA.csv")

# 컬럼해더 재정의
customerData.columns = ['CUSTID','AVGPRICE','EMI','DEVICECOUNT','PRODUCTAGE','CUSTTYPE']

## 데이터프레임 생성
customerData = pd.DataFrame(customerData)
customerData
# Out:
#      CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0    A13566  4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1    A14219  3642.441950    2          4.0    2.682023      Sleeping-dog
# 2    A15312  3653.884565    2          5.0    3.208202      Sleeping-dog
# 3    A16605  3713.211107    2          6.6    0.900000        Early-bird
# 4    B10634  3391.074215    2          4.2    2.453656      Sleeping-dog
# 5    B16849  3755.263391    2          4.7    2.786665      Sleeping-dog
# 6    B18816  3213.911446    2          6.4    0.900000        Early-bird
# 7    C10639  3516.500000    2          5.2    2.564830  Big-Screen-lover
# 8    C12717  3732.900000    2          5.7    2.069995  Big-Screen-lover
# 9    C15050  4020.173425    2          4.9    3.013440      Sleeping-dog
# 10   C18306  4005.005142    2          4.7    3.113618      Sleeping-dog
# 11   C18622  3246.000000    1          5.0    1.891624  Big-Screen-lover
# ...

# %%
customerData["TEST"] = customerData["PRODUCTAGE"].rolling(window = 5, center = True).mean()
customerData.head(10)
# Out:
#    CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0  A13566  4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219  3642.441950    2          4.0    2.682023      Sleeping-dog
# 2  A15312  3653.884565    2          5.0    3.208202      Sleeping-dog
# 3  A16605  3713.211107    2          6.6    0.900000        Early-bird
# 4  B10634  3391.074215    2          4.2    2.453656      Sleeping-dog
# 5  B16849  3755.263391    2          4.7    2.786665      Sleeping-dog
# 6  B18816  3213.911446    2          6.4    0.900000        Early-bird
# 7  C10639  3516.500000    2          5.2    2.564830  Big-Screen-lover
# 8  C12717  3732.900000    2          5.7    2.069995  Big-Screen-lover
# 9  C15050  4020.173425    2          4.9    3.013440      Sleeping-dog
#
#        TEST
# 0       NaN
# 1       NaN
# 2  2.184612
# 3  2.406109
# 4  2.049705
# 5  1.921030
# 6  2.155029
# 7  2.266986
# 8  2.332377
# 9  2.530702

# %%
# 변경전 컬럼
customerData.columns
print(customerData.columns)

#컬럼명 전체 변경
customerData.columns = \
["CUSTID","AVGPRICE","EMI", \
 "DEVICECOUNT", "PRODUCTAGE", "CUSTTYPE", "TEST"]

customerData
# Out:
# Index(['CUSTID', 'AVGPRICE', 'EMI', 'DEVICECOUNT', 'PRODUCTAGE', 'CUSTTYPE',
#        'TEST'],
#       dtype='object')
#      CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0    A13566  4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1    A14219  3642.441950    2          4.0    2.682023      Sleeping-dog
# 2    A15312  3653.884565    2          5.0    3.208202      Sleeping-dog
# 3    A16605  3713.211107    2          6.6    0.900000        Early-bird
# 4    B10634  3391.074215    2          4.2    2.453656      Sleeping-dog
# 5    B16849  3755.263391    2          4.7    2.786665      Sleeping-dog
# 6    B18816  3213.911446    2          6.4    0.900000        Early-bird
# 7    C10639  3516.500000    2          5.2    2.564830  Big-Screen-lover
# 8    C12717  3732.900000    2          5.7    2.069995  Big-Screen-lover
# 9    C15050  4020.173425    2          4.9    3.013440      Sleeping-dog
# ...

# %%
#컬럼명 부분 변경
renamedData = customerData.rename(columns={"TEST": "RENAME_COLUMN"})

# %%
renamedData
# Out:
#      CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0    A13566  4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1    A14219  3642.441950    2          4.0    2.682023      Sleeping-dog
# 2    A15312  3653.884565    2          5.0    3.208202      Sleeping-dog
# 3    A16605  3713.211107    2          6.6    0.900000        Early-bird
# 4    B10634  3391.074215    2          4.2    2.453656      Sleeping-dog
# 5    B16849  3755.263391    2          4.7    2.786665      Sleeping-dog
# 6    B18816  3213.911446    2          6.4    0.900000        Early-bird
# 7    C10639  3516.500000    2          5.2    2.564830  Big-Screen-lover
# 8    C12717  3732.900000    2          5.7    2.069995  Big-Screen-lover
# 9    C15050  4020.173425    2          4.9    3.013440      Sleeping-dog
# 10   C18306  4005.005142    2          4.7    3.113618      Sleeping-dog
# 11   C18622  3246.000000    1          5.0    1.891624  Big-Screen-lover
# ...

# %% [markdown]
# ### 컬럼 값 바꾸기 #1 → 데이터프레임명[‘컬럼명‘].iloc[index]=2
# ### 컬럼 값 바꾸기 #2 → 데이터프레임명[‘컬럼명’].iloc[index] = 데이터프레임명[‘컬럼명’].iloc[0:5].mean()

# %%
renamedData['RENAME_COLUMN'].loc[0:]=1
renamedData
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#      CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0    A13566  4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1    A14219  3642.441950    2          4.0    2.682023      Sleeping-dog
# 2    A15312  3653.884565    2          5.0    3.208202      Sleeping-dog
# 3    A16605  3713.211107    2          6.6    0.900000        Early-bird
# 4    B10634  3391.074215    2          4.2    2.453656      Sleeping-dog
# 5    B16849  3755.263391    2          4.7    2.786665      Sleeping-dog
# 6    B18816  3213.911446    2          6.4    0.900000        Early-bird
# ...

# %%
renamedData['RENAME_COLUMN'].loc[0:]=renamedData['PRODUCTAGE'].loc[0:5].mean()
renamedData
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#      CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0    A13566  4273.900000    3          6.4    2.284955  Big-Screen-lover
# 1    A14219  3642.441950    2          4.0    2.284955      Sleeping-dog
# 2    A15312  3653.884565    2          5.0    2.284955      Sleeping-dog
# 3    A16605  3713.211107    2          6.6    2.284955        Early-bird
# 4    B10634  3391.074215    2          4.2    2.284955      Sleeping-dog
# 5    B16849  3755.263391    2          4.7    2.284955      Sleeping-dog
# 6    B18816  3213.911446    2          6.4    2.284955        Early-bird
# ...

# %% [markdown]
# ### 데이터합치기
# ### 데이터 조인 : pd. merge(데이터프레임명1, 데이터프레임명2, left_on=‘데이터프레임1 조인 키’                                                right_on=‘데이터프레임2 조인 키’, how = “left”)
# ### how 파라미터 기본값은 inner

# %%
import pandas as pd
from sqlalchemy import create_engine 
 
# DB 커넥션 열기
engine = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl') 

# DB 테이블을 읽어 Data Frame 변수에 저장하기
regionMasterData = pd.read_sql_query('SELECT * FROM KOPO_REGION_MST', engine) 
selectExample = pd.read_sql_query('SELECT * FROM KOPO_CHANNEL_SEASONALITY_NEW', engine) 


# 데이터 VIEW
print(regionMasterData.head())
# Out:
#   regionid regionname
# 0      A00       아프리카
# 1      A01         미국
# 2      A02         한국
# 3      A03         독일
# 4      A04        브라질

# %%
print(selectExample.head())
# Out:
#   regionid    product yearweek      qty
# 0      A60   PRODUCT4   201402     71.0
# 1      A60  PRODUCT59   201402  22275.0
# 2      A60  PRODUCT34   201402   4463.0
# 3      A60  PRODUCT47   201402      0.0
# 4      A60  PRODUCT56   201402     23.0

# %%
# 데이터 조인
pd.merge(regionMasterData, selectExample,\
         left_on='regionid', right_on = 'regionid')\
[['regionid','regionname','product','yearweek','qty']]
# Out:
#        regionid regionname    product yearweek       qty
# 0           A00       아프리카  PRODUCT58   201404       0.0
# 1           A00       아프리카  PRODUCT59   201404    8553.0
# 2           A00       아프리카  PRODUCT34   201404     532.0
# 3           A00       아프리카  PRODUCT58   201401       0.0
# 4           A00       아프리카  PRODUCT59   201401    9988.0
# 5           A00       아프리카  PRODUCT34   201401     661.0
# 6           A00       아프리카  PRODUCT58   201402       0.0
# 7           A00       아프리카  PRODUCT59   201402    9005.0
# 8           A00       아프리카  PRODUCT34   201402     679.0
# 9           A00       아프리카  PRODUCT58   201403       0.0
# 10          A00       아프리카  PRODUCT59   201403    8416.0
# 11          A00       아프리카  PRODUCT34   201403     578.0
# 12          A00       아프리카  PRODUCT58   201406       0.0
# 13          A00       아프리카  PRODUCT59   201406   13799.0
# 14          A00       아프리카  PRODUCT34   201406     423.0
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine 
 
# DB 커넥션 열기
engine = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl') 
NewData = pd.read_sql_query('SELECT * FROM KOPO_CHANNEL_SEASONALITY_NEW', engine)

# %%
NewData
# Out:
#        regionid    product yearweek       qty
# 0           A60   PRODUCT4   201402      71.0
# 1           A60  PRODUCT59   201402   22275.0
# 2           A60  PRODUCT34   201402    4463.0
# 3           A60  PRODUCT47   201402       0.0
# 4           A60  PRODUCT56   201402      23.0
# 5           A60  PRODUCT57   201402      14.0
# 6           A60  PRODUCT12   201402    1186.0
# 7           A60   PRODUCT1   201402       7.0
# 8           A60  PRODUCT33   201402     101.0
# 9           A60  PRODUCT62   201402     336.0
# 10          A37  PRODUCT58   201402       0.0
# 11          A37  PRODUCT59   201402   11492.0
# 12          A37  PRODUCT34   201402     825.0
# 13          A31  PRODUCT58   201402       0.0
# 14          A31  PRODUCT59   201402     560.0
# 15          A31  PRODUCT34   201402     103.0
# 16          A04  PRODUCT58   201402       0.0
# 17          A04  PRODUCT63   201402     740.0
# 18          A04  PRODUCT15   201402     394.0
# ...

# %%
groupData = NewData.groupby(["regionid","product"], as_index=False)[["qty"]].mean()
groupData
# Out:
#     regionid    product            qty
# 0        A00  PRODUCT34     132.445860
# 1        A00  PRODUCT58     105.235669
# 2        A00  PRODUCT59   36086.547771
# 3        A01   PRODUCT1    5716.726115
# 4        A01  PRODUCT12  197052.777070
# 5        A01  PRODUCT14   17934.738854
# 6        A01  PRODUCT15    4759.554140
# 7        A01  PRODUCT16    1392.394904
# 8        A01  PRODUCT19    3335.140127
# 9        A01   PRODUCT2   22769.891720
# 10       A01  PRODUCT20      62.955414
# 11       A01  PRODUCT33   11919.828025
# 12       A01  PRODUCT34  108633.229299
# 13       A01   PRODUCT4   25851.547771
# 14       A01  PRODUCT47   10998.159236
# 15       A01  PRODUCT56    6296.229299
# 16       A01  PRODUCT57    6804.643312
# 17       A01  PRODUCT58   27346.216561
# 18       A01  PRODUCT59  642760.585987
# 19       A01   PRODUCT6     800.222930
# 20       A01  PRODUCT60       0.636943
# 21       A01  PRODUCT62   11378.993631
# 22       A01  PRODUCT63   47715.101911
# ...

# %%
mergeData= pd.merge(selectExample, groupData, \
            on=["regionid","product"], suffixes=('_a', '_b'), how="left")

# %%
mergeData
# Out:
#        regionid    product yearweek     qty_a          qty_b
# 0           A60   PRODUCT4   201402      71.0      44.662420
# 1           A60  PRODUCT59   201402   22275.0   35366.050955
# 2           A60  PRODUCT34   201402    4463.0    6117.560510
# 3           A60  PRODUCT47   201402       0.0       0.363057
# 4           A60  PRODUCT56   201402      23.0      18.560510
# 5           A60  PRODUCT57   201402      14.0     147.248408
# 6           A60  PRODUCT12   201402    1186.0    1216.171975
# 7           A60   PRODUCT1   201402       7.0       3.522293
# 8           A60  PRODUCT33   201402     101.0      60.719745
# 9           A60  PRODUCT62   201402     336.0     328.993631
# 10          A37  PRODUCT58   201402       0.0      23.343949
# 11          A37  PRODUCT59   201402   11492.0   25383.292994
# 12          A37  PRODUCT34   201402     825.0    1253.121019
# 13          A31  PRODUCT58   201402       0.0      41.401274
# ...

# %%
mergeData["ratio"] = mergeData["qty_a"] / mergeData["qty_b"]
mergeData
# Out:
#        regionid    product yearweek     qty_a          qty_b      ratio
# 0           A60   PRODUCT4   201402      71.0      44.662420   1.589703
# 1           A60  PRODUCT59   201402   22275.0   35366.050955   0.629841
# 2           A60  PRODUCT34   201402    4463.0    6117.560510   0.729539
# 3           A60  PRODUCT47   201402       0.0       0.363057   0.000000
# 4           A60  PRODUCT56   201402      23.0      18.560510   1.239190
# 5           A60  PRODUCT57   201402      14.0     147.248408   0.095077
# 6           A60  PRODUCT12   201402    1186.0    1216.171975   0.975191
# 7           A60   PRODUCT1   201402       7.0       3.522293   1.987342
# 8           A60  PRODUCT33   201402     101.0      60.719745   1.663380
# 9           A60  PRODUCT62   201402     336.0     328.993631   1.021296
# 10          A37  PRODUCT58   201402       0.0      23.343949   0.000000
# 11          A37  PRODUCT59   201402   11492.0   25383.292994   0.452739
# ...

# %% [markdown]
# ### 데이터 조인 : pd. concat([데이터프레임명1, 데이터프레임명2])

# %%
import numpy as np

# A01 데이터 정제
a01data = selectExample[(selectExample['regionid']=='A01')]
print(len(a01data))
print(a01data.count())

# A71 데이터 정제
a71data = selectExample[(selectExample['regionid']=='A50')]
a71data['qty'] = np.where(a71data['qty'] < 500,500,a71data['qty'])
print(len(a71data))
print(a71data.count())

# # 데이터 결과 값 MERGE
# mergedata = pd.concat([a01data, a71data], axis=1)
# print(len(mergedata))

mergedata = pd.concat([a01data, a71data])
print(mergedata.count())
# Out:
# 3611
# regionid    3611
# product     3611
# yearweek    3611
# qty         3611
# dtype: int64
# 1884
# regionid    1884
# product     1884
# yearweek    1884
# qty         1884
# dtype: int64
# regionid    5495
# product     5495
# yearweek    5495
# qty         5495
# dtype: int64
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# ### 1. PIVOT (행을 열로)

# %% [markdown]
# ### pivot : 데이터프레임명.pivot_table( index = [‘고정key컬럼1’,’고정key컬럼2’],                                            columns=‘pivot대상컬럼명’, values=‘피벗산대상컬럼’)

# %%
#  피벗 예시
pivotResult = selectExample.\
pivot_table(index = ['regionid','product'], columns='yearweek', values='qty')
finalResult = pivotResult.reset_index()
finalResult
# Out:
# yearweek regionid    product    201401    201402    201403    201404  \
# 0             A00  PRODUCT34     661.0     679.0     578.0     532.0
# 1             A00  PRODUCT58       0.0       0.0       0.0       0.0
# 2             A00  PRODUCT59    9988.0    9005.0    8416.0    8553.0
# 3             A01   PRODUCT1   14115.0    9169.0   21350.0    9457.0
# 4             A01  PRODUCT12  139564.0  109173.0  119281.0  139609.0
# 5             A01  PRODUCT14    9844.0    6363.0    8022.0    7562.0
# 6             A01  PRODUCT15    5684.0    4049.0    3689.0    4341.0
# 7             A01  PRODUCT16    1316.0     919.0    1018.0     905.0
# 8             A01  PRODUCT19    1519.0    2401.0    1513.0    2264.0
# 9             A01   PRODUCT2     225.0     203.0     236.0     203.0
# 10            A01  PRODUCT20      41.0       6.0      59.0      21.0
# 11            A01  PRODUCT33    7043.0    5337.0    6940.0    6041.0
# 12            A01  PRODUCT34   14836.0   12032.0   13514.0   13798.0
# ...

# %% [markdown]
# ### 2. UNPIVOT (열을 행으로)

# %%
# unpivot : 데이터프레임명.stack().reset_index(
unpivotResult=pivotResult.stack().reset_index()
unpivotResult.columns=\
['regionid','product','yearweek','qty']
print(unpivotResult)
# Out:
#        regionid    product yearweek      qty
# 0           A00  PRODUCT34   201401    661.0
# 1           A00  PRODUCT34   201402    679.0
# 2           A00  PRODUCT34   201403    578.0
# 3           A00  PRODUCT34   201404    532.0
# 4           A00  PRODUCT34   201405    516.0
# 5           A00  PRODUCT34   201406    423.0
# 6           A00  PRODUCT34   201407    407.0
# 7           A00  PRODUCT34   201408    364.0
# 8           A00  PRODUCT34   201409    470.0
# 9           A00  PRODUCT34   201410    538.0
# 10          A00  PRODUCT34   201411    369.0
# 11          A00  PRODUCT34   201412    352.0
# 12          A00  PRODUCT34   201413    354.0
# 13          A00  PRODUCT34   201414    312.0
# 14          A00  PRODUCT34   201415    295.0
# 15          A00  PRODUCT34   201416    284.0
# 16          A00  PRODUCT34   201417    237.0
# 17          A00  PRODUCT34   201418    180.0
# 18          A00  PRODUCT34   201419    161.0
# 19          A00  PRODUCT34   201420    140.0
# ...
